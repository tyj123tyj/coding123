# %%
x="I'm a student"
print(x)
# Out:
# I'm a student

# %%
a=float(input('請輸入x1座標:'))

b=float(input('請輸入x2座標:'))

c=float(input('請輸入y1座標:'))

d=float(input('請輸入y2座標:'))

e=((a-c)**2+(b-d)**2)**0.5

f='兩點距離:'
print(f)
print(e)
# Out:
# 請輸入x1座標:0
# 請輸入x2座標:0
# 請輸入y1座標:3
# 請輸入y2座標:4
# 兩點距離:
# 5.0

# %%
a=float(input('請輸入您的體重(kg)唷'))

b=float(input('請輸入您的身高(cm)唷'))

c=a/b**2*10000

d='BMI質是:'

print(d)
print(c)
# Out:
# 請輸入您的體重(kg)唷80
# 請輸入您的身高(cm)唷180
# BMI質是:
# 24.691358024691358
